# %%
import rawpy
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = 15, 10
from matplotlib.pyplot import imshow

# %%
# !ls  M42/SCIENCE/IMG_6853.CR2
# Out:
# M42/SCIENCE/IMG_6853.CR2

# %%
with rawpy.imread('../../Media/DATA/Imágenes/fotos_canon600d/first_ligth/IMG_0080.CR2') as raw:
    rgb = raw.postprocess(use_camera_wb=True,output_bps=16,user_flip=0)
    raw_image = raw.raw_image.copy()

# %%
print(rgb.dtype, rgb.shape)
rgb=rgb/rgb.max()
imshow(rgb)
# Out:
# uint16 (3465, 5202, 3)

# %%
import astropy.io.fits as fits
hdu = fits.PrimaryHDU((rgb[:,:,1],rgb[:,:,2],rgb[:,:,0]))
hdu.writeto('new.fits',overwrite=True)

# %%
imshow(raw_image/raw_image.max())

# %%
hdu = fits.PrimaryHDU(raw_image)
hdu.writeto('newraw.fits',overwrite=True)

# %%
mpl.pyplot.hist(raw_image.ravel(),bins=500)
# Out:
# (array([6.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00, 4.200000e+01, 2.400000e+01,
#         3.600000e+01, 3.000000e+00, 1.400000e+01, 1.000000e+00,
#         2.000000e+00, 0.000000e+00, 6.000000e+00, 4.000000e+00,
#         2.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00, 2.000000e+01, 3.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 1.000000e+00,
#         2.000000e+00, 1.000000e+00, 3.000000e+00, 1.000000e+00,
#         4.000000e+00, 3.000000e+00, 3.000000e+00, 7.100000e+01,
# ...
